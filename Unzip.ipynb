# %%
# !apt install unzip
# Out:
# ^C

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Finally

# %%
# !unzip -u "gdrive/MyDrive/SourceDir/SourceFile.zip" -d "gdrive/MyDrive/DestinationDir"
# Out:
# unzip:  cannot find or open gdrive/MyDrive/SourceDir/SourceFile.zip, gdrive/MyDrive/SourceDir/SourceFile.zip.zip or gdrive/MyDrive/SourceDir/SourceFile.zip.ZIP.

# %% [markdown]
# Usefull if you want to check directory structure

# %%
# !ls gdrive/MyDrive/Folder/
# Out:
# ls: cannot access 'gdrive/MyDrive/Folder/': No such file or directory
